# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img_path = r"/home/ychen921/808E/project2/Data/Set3/Set3/Oculus3/Oculus3-6.jpg"
img = cv2.imread(img_path)
img = img[:,:,::-1]
plt.imshow(img)

# %%
crop_img = img[400:900,710:1210]#[290:690, 750:1150]
plt.imshow(crop_img)

# %%
pro_img_path = r"/home/ychen921/808E/final_project/Dataset/Set1/8.png"
pro_img = cv2.imread(pro_img_path)
pro_img = cv2.cvtColor(pro_img, cv2.COLOR_BGR2GRAY)
# pro_img = pro_img[:,:,::-1]
plt.imshow(pro_img)

# %%
print(pro_img[193,0])
print(pro_img[499,175])
# denote_img = cv2.circle(pro_img, (0,193), 10, (255,255,255), -1) 
# denote_img = cv2.circle(pro_img, (175,499), 10, (255,255,255), -1) 
plt.imshow(pro_img)
# Out:
# 255
# 255
