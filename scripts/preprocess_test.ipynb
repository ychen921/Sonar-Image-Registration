# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img_path = r"/home/ychen921/808E/project2/Data/Set3/Set3/Oculus3/Oculus3-6.jpg"
img = cv2.imread(img_path)
img = img[:,:,::-1]
plt.imshow(img)

# %%
crop_img = img[290:690, 750:1150]
plt.imshow(crop_img)
